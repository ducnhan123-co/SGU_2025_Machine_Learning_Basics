# %%
import pandas as pd
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report

df4=pd.read_csv("data.csv")
df4.head()
# Out:
#   AnimalName symptoms1             symptoms2 symptoms3    symptoms4  \
# 0        Dog     Fever              Diarrhea  Vomiting  Weight loss
# 1        Dog     Fever              Diarrhea  Coughing    Tiredness
# 2        Dog     Fever              Diarrhea  Coughing     Vomiting
# 3        Dog     Fever  Difficulty breathing  Coughing     Lethargy
# 4        Dog     Fever              Diarrhea  Coughing     Lethargy
#
#      symptoms5 Dangerous
# 0  Dehydration       Yes
# 1        Pains       Yes
# 2     Anorexia       Yes
# 3     Sneezing       Yes
# 4     Blue Eye       Yes

# %%
X4 = pd.get_dummies(df4.drop(columns='Dangerous'))

y4 = df4['Dangerous'].map({'Yes': 1, 'No': 0})
# hoặc nếu bạn vẫn muốn get_dummies:
# y4 = pd.get_dummies(df4['Dangerous'], drop_first=True).iloc[:,0]

X_train4,X_test4,y_train4,y_test4= train_test_split(X4,y4,test_size=0.2,random_state=24)

kernels = ['linear','poly','rbf','sigmoid']
best_svm = None
best_val_acc = -1
best_kernel = None
for k in kernels:
    clf=svm.SVC(kernel=k,probability=True,class_weight='balanced')
    clf.fit(X_train4,y_train4)
    tmp_val_acc=clf.score(X_test4,y_test4)
    print(f"{k} kernel accuracy: {tmp_val_acc:.4f}")
    if tmp_val_acc > best_val_acc:
        best_val_acc = tmp_val_acc
        best_svm = clf
        best_kernel = k


print(f"\n✅ Best validation accuracy: {best_val_acc:.4f} with kernel = {best_kernel}")

# 5. In báo cáo chi tiết
y_pred4 = best_svm.predict(X_test4)
print("\nClassification Report:\n", classification_report(y_test4, y_pred4))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 15
#      13 for k in kernels:
#      14     clf=svm.SVC(kernel=k,probability=True,class_weight='balanced')
# ---> 15     clf.fit(X_train4,y_train4)
#      16     tmp_val_acc=clf.score(X_test4,y_test4)
#      17     print(f"{k} kernel accuracy: {tmp_val_acc:.4f}")
#
# File ~/active/myenv/lib/python3.13/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/active/myenv/lib/python3.13/site-packages/sklearn/svm/_base.py:197, in BaseLibSVM.fit(self, X, y, sample_weight)
# ...
