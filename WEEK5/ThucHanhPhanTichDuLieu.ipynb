# %% [markdown]
# # Thực hành : Phân tích khám phá dữ liệu

# %% [markdown]
# ## A.Mục tiêu

# %% [markdown]
# ## B.Kết cấu thực hành

# %% [markdown]
# ## C.Nội dung thực hành

# %% [markdown]
# ### 1.1. THỐNG KÊ MÔ TẢ

# %% [markdown]
# ### 1.1.1. Ôn tập lý thuyết
# + Thống kê mô tả là gì? Nó khác gì với thống kê suy luận (inferential statistics)?
# + Các thước đo thống kê mô tả chính (ví dụ: trung bình, trung vị, phương sai, độ lệch chuẩn) được sử
# dụng để làm gì? Trong trường hợp nào thì nên dùng trung vị thay vì trung bình?
# + Làm thế nào để xác định phân bố của một tập dữ liệu? Các loại phân bố phổ biến là gì (ví dụ: phân bố
# chuẩn, lệch trái, lệch phải)?
# + Độ lệch chuẩn và phạm vi (range) có ý nghĩa gì trong việc đánh giá sự phân tán của dữ liệu?
# + Sự khác biệt giữa các thước đo như Q1, Q2, Q3 trong biểu đồ hộp (boxplot) là gì?
# + Làm thế nào để xử lý giá trị thiếu (missing values) trước khi tính toán các chỉ số thống kê mô tả?
# + Bạn có thể giải thích cách đọc và diễn giải một biểu đồ histogram hoặc boxplot từ dữ liệu thực tế
# không?
# + Khi gặp một tập dữ liệu có giá trị ngoại lai (outliers), bạn sẽ xử lý chúng như thế nào trước khi thực hiện
# thống kê mô tả?

# %% [markdown]
# Câu 1
#
# + Thống kê mô tả (descriptive)
#   - Định nghĩa : Được dùng cho mô tả dữ các dữ liệu thiết yếu của nooi dung, cho biết được cacs đặc điểm toàn bộ dữ liệu như min,max,descrive,dtype
#   - Kết quả chính : Thu được tập dữ lieu thưc tế + các đồ thị ,trực quan ,để giúp hiễu rõ về dữ liệu
#   - Đặc trưng : độ lệch phải ->khi đồ lêch chuẩn hướng bên phải nhiều (? dữ liêu gì với gì bạn nhỉ?) , độ lệch trái ->lêch bên trái ?
#   - Hạn chế : khi có dữ liệu rất lớn cần phải làm sạch dữ liêu và thao tác nhiều hơn
# + Thống kê suy luận (inferential statistics)
#   - Định nghĩa: đươc dùng cho suy luận và dựa đoán dựa trên dữ liệu
#   - Kết quả chính : ? có thể được suy cho suy luận các mẫu ,dự đoán ,xác suất ,ước tính có sự không chắc chắn
#   - Đặc trưng : ?
# + Khác biệt
#   1. Mục đích
#   2. Phạm vi
#   3. Phương pháp
#   4. Đầu ra
#   5. Ví dụ

# %% [markdown]
# Câu 2
#
# - Các thước đo thống kê mô tả chính được sử dụng để biết các thống số chính của các loại dữ liệu và phạm vi của các giá trị trong khoảng nhỏ nhất -> lớn nhất,giúp phát hiện,rà soát các vấn đề trong dữ liệu ->phát hiện và sửa lỗi
# - Trung bình cộng (Mean): Tổng các giá trị chia cho số lượng quan sát. Dùng khi dữ liệu phân bố đều, không có nhiều giá trị ngoại lệ.
# - Trung vị (Median): Giá trị nằm giữa khi sắp xếp dữ liệu theo thứ tự. Dùng khi dữ liệu có nhiều ngoại lệ hoặc phân bố lệch, vì trung vị ít bị ảnh hưởng bởi giá trị cực đoan.
# - Phương sai (Variance): Đo mức độ phân tán của dữ liệu so với giá trị trung bình (bình phương độ lệch của từng quan sát so với trung bình, rồi chia cho số quan sát).
# - Độ lệch chuẩn (Standard Deviation): Căn bậc hai của phương sai. Cùng đơn vị với dữ liệu gốc, dễ so sánh hơn. Dùng để biết dữ liệu biến thiên mạnh hay yếu quanh giá trị trung bình.
# - Khi nên dugngf trung vị thay cho trung ihf: Khi dữ liệu có ngọai lệ (thu nhập ,giá nhà đất.. )-> vì trung bình sẽ bị keo lệch,còn trung vị phan ánh tốt hơn

# %% [markdown]
# Câu 3
# Xác định phân bố dữ liệu:
#
# - Quan sát đồ thị: dùng biểu đồ tần suất (histogram), biểu đồ mật độ (density plot), hoặc boxplot để xem hình dạng phân bố.
#
# - Chỉ số thống kê: so sánh mean – median (nếu lệch xa nhau thì dữ liệu bị lệch), tính hệ số lệch (skewness).
#
# - Kiểm định thống kê: các test như Shapiro-Wilk, Kolmogorov-Smirnov để kiểm tra dữ liệu có tuân theo phân bố chuẩn không.
#
# Các loại phân bố phổ biến:
#
# - Phân bố chuẩn (Normal distribution): Đối xứng quanh trung bình, hình chuông, mean = median = mode. Ít ngoại lệ.
#
# - Phân bố lệch trái (Left-skewed / Negative skew): Đuôi kéo dài về bên trái, giá trị nhỏ cực đoan nhiều hơn. → mean < median.
#
# - Phân bố lệch phải (Right-skewed / Positive skew): Đuôi kéo dài về bên phải, giá trị lớn cực đoan nhiều hơn. → mean > median.

# %% [markdown]
# Câu 4
#
# Phạm vi (Range):
#
# - Công thức = Giá trị lớn nhất – giá trị nhỏ nhất.
#
# - Cho biết dữ liệu “trải rộng” trong khoảng nào.
#
# - Nhược điểm: rất nhạy cảm với ngoại lệ (outlier).
#
# Độ lệch chuẩn (Standard Deviation):
#
# - Là căn bậc hai của phương sai.
#
# - Đo mức độ dữ liệu phân tán quanh giá trị trung bình.
#
# - Độ lệch chuẩn nhỏ → dữ liệu tập trung gần trung bình;
# - Độ lệch chuẩn lớn → dữ liệu biến thiên nhiều.
#
# - Ít bị ảnh hưởng cực đoan như range, mô tả toàn bộ dữ liệu tốt hơn.
#
# -
# -->
#
#
# - Range = độ rộng toàn bộ dữ liệu (nhưng dễ bị outlier chi phối).
# - Standard Deviation = độ phân tán trung bình của dữ liệu quanh mean (ổn định và thường dùng hơn).

# %% [markdown]
# Câu 5
#
# - thước đo Q1 trong biếu đồ boxplot : lớn hơn 25% dữ liệu và nhỏ hơn 70%
# - thước đo Q2 : giá trị trung bình (trung vị median 50%)
# - thước đo Q3 : lớn hơn 75% dư liệu và nhỏ hơn 25%

# %% [markdown]
# Câu 6
#
# 1. Xóa dữ liệu (Remove/Drop):
#
# - Xóa quan sát (row) hoặc thuộc tính (column) có giá trị thiếu.
#
# - Dùng khi dữ liệu thiếu ít và không ảnh hưởng nhiều.
#
# 2. Thay thế giá trị (Imputation):
#
# - Mean/Median: thay bằng trung bình hoặc trung vị (median thường tốt hơn khi có ngoại lệ).
#
# - Mode: dùng cho dữ liệu phân loại (categorical).
#
# 3. Giá trị lân cận (Forward/Backward fill): áp dụng cho dữ liệu chuỗi thời gian.
#
# - Mô hình dự đoán: dùng các thuật toán (k-NN, regression) để ước lượng giá trị bị thiếu.
#
# - Giữ nguyên (nếu công cụ hỗ trợ):
#
# - Một số mô hình/method có thể xử lý trực tiếp missing values.

# %% [markdown]
# Câu 7
#
# - Các đọc va dien i 1 biểu dò histogram hoặc boxplot
# - 📊 1. Histogram (biểu đồ tần suất)
#
# Cách đọc:
#
# Trục X = giá trị (giá trị của biến).
#
# Trục Y = tần suất / số lần xuất hiện của giá trị trong khoảng (bin).
#
# Mỗi cột = số lượng quan sát rơi vào khoảng đó.
#
# Cách diễn giải:
#
# Hình chuông cân đối → dữ liệu có thể gần phân bố chuẩn.
#
# Lệch trái (đuôi bên trái dài) → nhiều giá trị nhỏ bất thường, mean < median.
#
# Lệch phải (đuôi bên phải dài) → nhiều giá trị lớn bất thường, mean > median.
#
# Cột cao vọt lên ở một vùng → tập trung dữ liệu ở khoảng đó.
#
# Khoảng trống lớn hoặc nhiều cột rải rác → dữ liệu phân tán, không đồng đều.
#
# Ví dụ: Histogram điểm thi → thấy đa số học sinh đạt 6–8 điểm, ít bạn dưới 3 hoặc trên 9 → dữ liệu phân bố gần chuẩn, tập trung ở mức trung bình khá.
#
# 📦 2. Boxplot (biểu đồ hộp)
#
# Cách đọc:
#
# Vạch giữa hộp = median (trung vị).
#
# Đầu dưới và đầu trên hộp = Q1 (25%) và Q3 (75%).
#
# Chiều cao hộp = IQR (Interquartile Range = Q3 - Q1).
#
# “Whiskers” (2 gạch vươn ra) = phạm vi dữ liệu không ngoại lệ.
#
# Các dấu chấm ngoài whiskers = outliers (giá trị ngoại lệ).
#
# Cách diễn giải:
#
# Hộp ngắn → dữ liệu tập trung.
#
# Hộp dài → dữ liệu phân tán rộng.
#
# Median nằm lệch về một phía → dữ liệu lệch trái hoặc lệch phải.
#
# Nhiều chấm bên ngoài → dữ liệu có nhiều ngoại lệ.
#
# Ví dụ: Boxplot thu nhập → median = 10 triệu, nhưng có vài điểm nằm xa ở phía phải (50–100 triệu) → dữ liệu lệch phải, tồn tại một số ít người thu nhập cực cao.

# %% [markdown]
# Câu 8
#
# - Xư y nogaj lai bằng nhữn cách như
# - Nếu outlier là do sai sót nhập liệu → Xóa hoặc sửa.
# - Nếu outlier là dữ liệu thật nhưng cực đoan → Giữ, hoặc thay bằng phương pháp Winsorizing / log transform.
# - Nếu outlier có ý nghĩa riêng biệt → Tách nhóm để phân tích riêng.

# %%
import matplotlib.pyplot as plt

# Dữ liệu giả: tuổi nghỉ hưu (đa số ~60, vài người nghỉ sớm bất thường 20-30 tuổi)
retire_age = [60, 61, 62, 59, 60, 61, 58, 63, 62, 59,
              60, 61, 62, 58, 25, 28, 30, 27, 26, 29]

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.hist(retire_age,bins=10,edgecolor='black')
plt.xlabel('tuoi nghi huu')
plt.ylabel('so nguoi')

plt.subplot(1,2,2)
plt.boxplot(retire_age,vert=False,patch_artist=True)
plt.xlabel("Tuổi nghỉ hưu");

plt.tight_layout();

# %% [markdown]
# ### 1.1.2 Bài làm mẫu
#
# #### Bài toán 1 : Thực hiện các nhiệm vụ trong bài toán 1 để làm quen với các thao tác cần làm để khám phá dữ liệu
#
# #### Nhiệm vụ 1: Khám phá dữ liệu COVID

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from owid import catalog
#       3 # Preview list of available datasets (each row = dataset)
#       4 catalogs.find(namespace="covid")
#
# ModuleNotFoundError: No module named 'owid'

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
#columns_name = ['ID','Year_Birth','Education','Marital_Status','Income','Kidhome','Teenhome','Dt_Customer','Recency','NumStorePurchases','NumWebVisitsMonth']
marketing_data = pd.read_csv("marketing_campaign.csv", sep="\t")
marketing_data = marketing_data[['ID','Year_Birth','Education',
 'Marital_Status','Income','Kidhome','Teenhome',
 'Dt_Customer','Recency','NumStorePurchases',
 'NumWebVisitsMonth']]

# %%
marketing_data.head()
# Out:
#      ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
#
#   Dt_Customer  Recency  NumStorePurchases  NumWebVisitsMonth
# 0  04-09-2012       58                  4                  7
# 1  08-03-2014       38                  2                  5
# 2  21-08-2013       26                 10                  4
# 3  10-02-2014       26                  4                  6
# 4  19-01-2014       94                  6                  5

# %% [markdown]
# 2 . Loại bỏ dữ liệu trùng lặp

# %%
marketing_data_duplicate = marketing_data.drop_duplicates()

marketing_data.drop(labels=[1],axis=0)

#marketing_data.drop(labels=['Year_Birth'],axis=1)
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      5524        1957  Graduation         Single  58138.0        0
# 2      4141        1965  Graduation       Together  71613.0        0
# 3      6182        1984  Graduation       Together  26646.0        1
# 4      5324        1981         PhD        Married  58293.0        1
# 5      7446        1967      Master       Together  62513.0        0
# ...     ...         ...         ...            ...      ...      ...
# 2235  10870        1967  Graduation        Married  61223.0        0
# 2236   4001        1946         PhD       Together  64014.0        2
# 2237   7270        1981  Graduation       Divorced  56981.0        0
# 2238   8235        1956      Master       Together  69245.0        0
# 2239   9405        1954         PhD        Married  52869.0        1
#
#       Teenhome Dt_Customer  Recency  NumStorePurchases  NumWebVisitsMonth
# ...

# %% [markdown]
# 3. Thay thế dữ liệu và thay đổi định dạng dữ liệu

# %%
marketing_data['Teenhome_replaced']=marketing_data['Teenhome'].replace([0,1,2],['has no teen','has teen','has teen'])

# Fill nas in the outcome
marketing_data['Income']=marketing_data['Income'].fillna(0)

marketing_data['Income_changed']=marketing_data['Income'].astype(int)

# %% [markdown]
# 4. Xử lý dữ liệu thiếu

# %%
marketing_data.isnull().sum()
marketing_data_withoutna = marketing_data.dropna(how='any')
marketing_data_withoutna.shape
# Out:
# (2240, 13)

# %% [markdown]
# #### Bài tập thực hành 1
# 1. Thực hiện thống kê mô tả trên tập dữ liệu về phân loại chất lượng rượu đỏ.
# Dữ liệu lấy tại https://www.kaggle.com/code/eisgandar/red-wine-quality-eda-classification
#
# 2. Thực hiện thống kê mô tả trên tập dữ liệu về bệnh tiểu đường. Dữ liệu lấy tại
# https://www.kaggle.com/code/vincentlugat/pima-indians-diabetes-eda-prediction-0-906

# %% [markdown]
# ### Bai 1

# %%
import numpy as np
import pandas as pd

# %%
redWine_df=pd.read_csv("winequality-red.csv")
redWine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
redWine_df.shape
# Out:
# (1599, 12)

# %%
redWine_df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
redWine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
redWine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
redWine_df.corr(method='pearson')
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
redWine_df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
redWine_df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# kiem tra co gia tri trung lap khong va co bao nhieu gia tri trung

# %%
# kiem tra xem c

# %% [markdown]
# ### Bài 2

# %%
import numpy as np
import pandas as pd

# %%
column_names = ["pregnancies","glucose","blood_pressure","skin_thickness","insulin","bmi","dpf","age","class"]
diabetes_df = pd.read_csv("pima-indians-diabetes.data.csv",names=column_names)

# %%
diabetes_df.head()
# Out:
#    pregnancies  glucose  blood_pressure  skin_thickness  insulin   bmi    dpf  \
# 0            6      148              72              35        0  33.6  0.627
# 1            1       85              66              29        0  26.6  0.351
# 2            8      183              64               0        0  23.3  0.672
# 3            1       89              66              23       94  28.1  0.167
# 4            0      137              40              35      168  43.1  2.288
#
#    age  class
# 0   50      1
# 1   31      0
# 2   32      1
# 3   21      0
# 4   33      1

# %%
diabetes_df_duplicate=diabetes_df.drop_duplicates()
diabetes_df_duplicate.head()
# Out:
#    pregnancies  glucose  blood_pressure  skin_thickness  insulin   bmi    dpf  \
# 0            6      148              72              35        0  33.6  0.627
# 1            1       85              66              29        0  26.6  0.351
# 2            8      183              64               0        0  23.3  0.672
# 3            1       89              66              23       94  28.1  0.167
# 4            0      137              40              35      168  43.1  2.288
#
#    age  class
# 0   50      1
# 1   31      0
# 2   32      1
# 3   21      0
# 4   33      1

# %%
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pregnancies     768 non-null    int64
#  1   glucose         768 non-null    int64
#  2   blood_pressure  768 non-null    int64
#  3   skin_thickness  768 non-null    int64
#  4   insulin         768 non-null    int64
#  5   bmi             768 non-null    float64
#  6   dpf             768 non-null    float64
#  7   age             768 non-null    int64
#  8   class           768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %%
diabetes_df.describe()
# Out:
#        pregnancies     glucose  blood_pressure  skin_thickness     insulin  \
# count   768.000000  768.000000      768.000000      768.000000  768.000000
# mean      3.845052  120.894531       69.105469       20.536458   79.799479
# std       3.369578   31.972618       19.355807       15.952218  115.244002
# min       0.000000    0.000000        0.000000        0.000000    0.000000
# 25%       1.000000   99.000000       62.000000        0.000000    0.000000
# 50%       3.000000  117.000000       72.000000       23.000000   30.500000
# 75%       6.000000  140.250000       80.000000       32.000000  127.250000
# max      17.000000  199.000000      122.000000       99.000000  846.000000
#
#               bmi         dpf         age       class
# count  768.000000  768.000000  768.000000  768.000000
# mean    31.992578    0.471876   33.240885    0.348958
# std      7.884160    0.331329   11.760232    0.476951
# min      0.000000    0.078000   21.000000    0.000000
# ...

# %%
diabetes_df['class'].value_counts()
# Out:
# class
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

col="glucose"

plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.histplot(diabetes_df[col],bins=30,edgecolor='black',kde=True)
plt.xlabel(col)
plt.title(f"Hist of {col}")
plt.ylabel("Freq")

plt.subplot(1,3,2)
plt.boxplot(diabetes_df[col],vert=False)
plt.xlabel(col)
plt.tight_layout()

# %%
outcome_counts=diabetes_df["class"].value_counts()
plt.figure(figsize=(6,6))

plt.pie(outcome_counts,labels=outcome_counts.index.map({
    0:"ko tieu duong",
    1:"Bi tieu duong"
}),autopct="%1.1f%%",startangle=90,colors=['skyblue','salmon']);

# %% [markdown]
# # 1.2 Xử lý và trực quan hóa dữ liệu

# %% [markdown]
# ### 1.2.2 Bài làm mẫu

# %% [markdown]
# ### 1. Chuẩn bị dữ liệu cho trực quan hóa dữ liệu

# %%
import pandas as pd 
import matplotlib.pyplot as plt
houseprices_data=pd.read_csv("HousingPrices-Amsterdam-August-2021.csv")
houseprices_data=houseprices_data[['Zip','Price','Area','Room']]
houseprices_data['PriceperSqm']=houseprices_data['Price']/houseprices_data['Area']
houseprices_data
# Out:
#          Zip     Price  Area  Room   PriceperSqm
# 0    1091 CR  685000.0    64     3  10703.125000
# 1    1059 EL  475000.0    60     3   7916.666667
# 2    1097 SM  850000.0   109     4   7798.165138
# 3    1060 TH  580000.0   128     6   4531.250000
# 4    1036 KN  720000.0   138     5   5217.391304
# ..       ...       ...   ...   ...           ...
# 919  1097 AE  750000.0   117     1   6410.256410
# 920  1033 CP  350000.0    72     3   4861.111111
# 921  1058 AK  350000.0    51     3   6862.745098
# 922  1095 MB  599000.0   113     4   5300.884956
# 923  1068 JS  300000.0    79     4   3797.468354
#
# [924 rows x 5 columns]

# %% [markdown]
# ### 2. Trực quan hóa dữ liệu với Matplotlib

# %%
houseprices_sorted=houseprices_data.sort_values('Price',ascending=False)
#houseprices_sorted.head()

# case 1 : basic
plt.figure(figsize=(12,6))
x=houseprices_sorted['Zip'][0:10]
y=houseprices_sorted['Price'][0:10]
#type(x) # panda series van dung nhu mang được 
plt.bar(x,y);

# %%
# case 2: advanced 1 
plt.figure(figsize=(12,6))
plt.bar(x,y)
plt.title('Top 10 Areas with the height house',fontsize=15)
plt.xlabel('Zip code',fontsize=12)
plt.xticks(fontsize=10)
plt.ylabel('House prices in millions', fontsize=12)
plt.yticks(fontsize=10);

# %%
#case 3 advanced 2 
fig ,ax = plt.subplots(figsize=(40,18))
x=houseprices_sorted['Zip'][0:10]
y=houseprices_sorted['Price'][0:10]

y1=houseprices_sorted['PriceperSqm'][0:10]

plt.subplot(1,2,1)
plt.bar(x,y)
plt.xticks(fontsize=17)
plt.ylabel('House prices in millions', fontsize=25)
plt.yticks(fontsize=20)
plt.title('Top 10 Areas with the highest house prices',
fontsize=25);

plt.subplot(1,2,2)
plt.bar(x,y1)
plt.xticks(fontsize=17)
plt.ylabel('House prices per sqm', fontsize=25)
plt.yticks(fontsize=20)
plt.title('Top 10 Areas with the highest house prices per sqm',
fontsize=25);

# %% [markdown]
# ## 3.Trực quan hóa dữ liệu với thư viên Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#case 1 : basic
plt.figure(figsize=(12,6))
data=houseprices_sorted[0:10]
sns.barplot(data=data,x='Zip',y='Price');

# %%
#case 2 : advanced 1
plt.figure(figsize= (12,6))
data = houseprices_sorted[0:10]
ax = sns.barplot(data= data, x= 'Zip',y = 'Price')
ax.set_xlabel('Zip code',fontsize = 15)
ax.set_ylabel('House prices in millions', fontsize = 15)
ax.set_title('Top 10 Areas with the highest house prices', fontsize= 20)
# Out:
# Text(0.5, 1.0, 'Top 10 Areas with the highest house prices')

# %%
# case 3
fig , ax = plt.subplots(1,2,figsize=(40,18))

data=houseprices_sorted[0:10]
sns.set(font_scale=3)
ax1=sns.barplot(data=data,x='Zip',y='Price',ax=ax[0])
ax1.set_xlabel('Zip code')
ax1.set_ylabel('House prices in millions')
ax1.set_title('Top 10 Areas with the highest house prices')

ax2= sns.barplot(data=data,x='Zip',y='PriceperSqm',ax=ax[1])
ax2.set_xlabel('Zip code')
ax2.set_ylabel('House prices per sqm')
ax2.set_title('Top 10 Areas with the highest price per sqm');
