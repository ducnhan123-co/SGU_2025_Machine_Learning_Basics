# %% [markdown]
# **<h1>Bài tập thục hành về EDA</h1>**

# %% [markdown]
# # **I. Thống kê mô tả**

# %% [markdown]
# ## Bài 1: Thực hiện thống kê mô tả trên tập dữ liệu về phân loại chất lượng rượu đỏ.
# Dữ liệu lấy tại https://www.kaggle.com/code/eisgandar/red-wine-quality-eda-classification

# %% [markdown]
# ### **1. TỔNG QUAN (Phần chung cho cả 3 phần bài tập)**

# %% [markdown]
# #### 1.1. Tóm tắt bài toán

# %% [markdown]
# <!-- Mô tả sơ vấn đề bài toán -->
# Mô tả bài toán

# %% [markdown]
# #### 1.2. Mô tả các biến

# %% [markdown]
# <!-- Giải thích sơ các biến -->
# Giải thích các biến (giống phần description tuần trước)

# %% [markdown]
# ### **2. THỰC HÀNH**

# %% [markdown]
# #### 2.1. Tính mean, median, mode, variance, standard deviation, range, percentile, quartile, interquartile range (IQR) sử dụng thư viện numpy và stats trên tập dữ liệu

# %%
# Thực hiện code ở đây (tương tự trong file pdf)

# %% [markdown]
# <!-- Giải thích các code -->
# Giải thích code

# %% [markdown]
# #### 2.2. Loại bỏ dữ liệu trùng lặp, thay thế dữ liệu và thay đổi định dạng của dữ liệu và xử lý dữ liệu thiếu

# %%
# Thực hiện code ở đây (tương tự trong file pdf)

# %% [markdown]
# <!-- Giải thích các code -->
# Giải thích code

# %% [markdown]
# ---

# %% [markdown]
# ## Bài 2: Thực hiện thống kê mô tả trên tập dữ liệu về bệnh tiểu đường.
# Dữ liệu lấy tại:
# https://www.kaggle.com/code/vincentlugat/pima-indians-diabetes-eda-prediction-0-906

# %% [markdown]
# ### **1. TỔNG QUAN (Phần chung cho cả 3 phần bài tập)**

# %% [markdown]
# #### 1.1. Tóm tắt bài toán

# %% [markdown]
# <!-- Mô tả sơ vấn đề bài toán -->
# Mô tả bài toán

# %% [markdown]
# #### 1.2. Mô tả các biến

# %% [markdown]
# <!-- Giải thích sơ các biến -->
# Giải thích các biến (giống phần description tuần trước)

# %% [markdown]
# ### **2. THỰC HÀNH**

# %% [markdown]
# #### 2.1. Tính mean, median, mode, variance, standard deviation, range, percentile, quartile, interquartile range (IQR) sử dụng thư viện numpy và stats trên tập dữ liệu

# %%
# Thực hiện code ở đây (tương tự trong file pdf)

# %% [markdown]
# <!-- Giải thích các code -->
# Giải thích code

# %% [markdown]
# #### 2.2. Loại bỏ dữ liệu trùng lặp, thay thế dữ liệu và thay đổi định dạng của dữ liệu và xử lý dữ liệu thiếu

# %%
# Thực hiện code ở đây (tương tự trong file pdf)

# %% [markdown]
# <!-- Giải thích các code -->
# Giải thích code

# %% [markdown]
# # **II. Xử lý và trực quan hóa dữ liệu**

# %% [markdown]
# ## Bài 1: Thực hiện trực quan hóa dữ liệu trên tập dữ liệu về phân loại chất lượng rượu đỏ.
# Dữ liệu lấy tại
# https://www.kaggle.com/code/eisgandar/red-wine-quality-eda-classification

# %% [markdown]
# ### **1. TỔNG QUAN (Phần chung cho cả 3 phần bài tập)**

# %% [markdown]
# #### 1.1. Tóm tắt bài toán

# %% [markdown]
# <!-- Mô tả sơ vấn đề bài toán -->
# Mô tả bài toán

# %% [markdown]
# #### 1.2. Mô tả các biến

# %% [markdown]
# <!-- Giải thích sơ các biến -->
# Giải thích các biến (giống phần description tuần trước)

# %% [markdown]
# ### **2. THỰC HÀNH**

# %% [markdown]
# #### 2.1 Chuẩn bị dữ liệu cho trực quan hóa dữ liệu, trực quan hóa dữ liệu với thư viện Matplotlib và Seaborn

# %%
# Thực hiện code ở đây (giống trong file pdf)

# %% [markdown]
# <!-- Giải thích code -->
# Giải thích code

# %% [markdown]
# ## Bài 2_1: Thực hiện trực quan hóa dữ liệu trên tập dữ liệu về bệnh tiểu đường.
# Dữ liệu lấy tại:
# https://www.kaggle.com/code/vincentlugat/pima-indians-diabetes-eda-prediction-0-906

# %% [markdown]
# ### **1. TỔNG QUAN (Phần chung cho cả 3 phần bài tập)**

# %% [markdown]
# #### 1.1. Tóm tắt bài toán

# %% [markdown]
# <!-- Mô tả sơ vấn đề bài toán -->
# Mô tả bài toán

# %% [markdown]
# #### 1.2. Mô tả các biến

# %% [markdown]
# <!-- Giải thích sơ các biến -->
# Giải thích các biến (giống phần description tuần trước)

# %% [markdown]
# ### **2. THỰC HÀNH**

# %% [markdown]
# #### 2.1 Chuẩn bị dữ liệu cho trực quan hóa dữ liệu, trực quan hóa dữ liệu với thư viện Matplotlib và Seaborn

# %%
# Thực hiện code ở đây (giống trong file pdf)

# %% [markdown]
# <!-- Giải thích code -->
# Giải thích code

# %% [markdown]
# ## Bài 2_2: Thực hiện EDA trên tập dữ liệu mua sắm tại siêu thị.
# Tập dữ liệu lấy từ:
# https://www.kaggle.com/code/rajatkumar30/eda-online-retail

# %% [markdown]
# ### **1. TỔNG QUAN (Phần chung cho cả 3 phần bài tập)**

# %% [markdown]
# #### 1.1. Tóm tắt bài toán

# %% [markdown]
# <!-- Mô tả sơ vấn đề bài toán -->
# Mô tả bài toán

# %% [markdown]
# #### 1.2. Mô tả các biến

# %% [markdown]
# <!-- Giải thích sơ các biến -->
# Giải thích các biến (giống phần description tuần trước)

# %% [markdown]
# ### **2. THỰC HÀNH**

# %% [markdown]
# #### 2.1 Chuẩn bị dữ liệu cho trực quan hóa dữ liệu, trực quan hóa dữ liệu với thư viện Matplotlib và Seaborn

# %% [markdown]
# a) Thêm thư viện và dữ liệu

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
online_retail_df = pd.read_csv("Online Retail.csv")

# %% [markdown]
# b) Quan sát tổng quan dữ liệu

# %%
online_retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
online_retail_df.shape
# Out:
# (541909, 8)

# %%
online_retail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
online_retail_df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
online_retail_df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
online_retail_df['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
online_retail_df['TotalAmount'] = online_retail_df['Quantity'] * online_retail_df['UnitPrice']
online_retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  TotalAmount
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom        15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom        20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom        22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom        20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom        20.34

# %%
online_retail_df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# TotalAmount         0
# dtype: int64

# %% [markdown]
# ### Cleaning data
# - Remove duplicate rows
# - Handling missing values
# - Convert columns to approriate datatypes
# - adding important columns

# %%
online_retail_df['CustomerID'] = online_retail_df['CustomerID'].fillna("Unknown")
online_retail_df.dropna(subset=['Description'],inplace=True)
online_retail_df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# TotalAmount    0
# dtype: int64

# %%
columns_drop = ['InvoiceNo','StockCode']
online_retail_df_cleaned = online_retail_df.drop(columns=columns_drop)
online_retail_df_cleaned.head()
# Out:
#                            Description  Quantity     InvoiceDate  UnitPrice  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6  12/1/2010 8:26       2.55
# 1                  WHITE METAL LANTERN         6  12/1/2010 8:26       3.39
# 2       CREAM CUPID HEARTS COAT HANGER         8  12/1/2010 8:26       2.75
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6  12/1/2010 8:26       3.39
# 4       RED WOOLLY HOTTIE WHITE HEART.         6  12/1/2010 8:26       3.39
#
#   CustomerID         Country  TotalAmount
# 0    17850.0  United Kingdom        15.30
# 1    17850.0  United Kingdom        20.34
# 2    17850.0  United Kingdom        22.00
# 3    17850.0  United Kingdom        20.34
# 4    17850.0  United Kingdom        20.34

# %% [markdown]
# <!-- Giải thích code -->
# Giải thích code

# %%
median = online_retail_df_cleaned.median(numeric_only=True)
median
# Out:
# Quantity       3.00
# UnitPrice      2.08
# TotalAmount    9.84
# dtype: float64

# %%
online_retail_df_cleaned['InvoiceDate'] = pd.to_datetime(
    online_retail_df_cleaned['InvoiceDate'], errors='coerce'
)

online_retail_df_cleaned['MonthYear']=online_retail_df_cleaned['InvoiceDate'].dt.to_period('M')
online_retail_df_cleaned.head()
# Out:
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    UnitPrice CustomerID         Country  TotalAmount MonthYear
# 0       2.55    17850.0  United Kingdom        15.30   2010-12
# 1       3.39    17850.0  United Kingdom        20.34   2010-12
# 2       2.75    17850.0  United Kingdom        22.00   2010-12
# 3       3.39    17850.0  United Kingdom        20.34   2010-12
# 4       3.39    17850.0  United Kingdom        20.34   2010-12

# %%
online_retail_df_cleaned['Year']=online_retail_df_cleaned['InvoiceDate'].dt.year

# %% [markdown]
# ### EDA

# %%
corrmat = online_retail_df_cleaned.corr(numeric_only=True)
f, ax = plt.subplots(figsize=(12,7))
sns.heatmap(data=corrmat, annot=True, vmin=-1, vmax=1, fmt=".2f", square=True, cmap="coolwarm")
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.scatterplot(y = 'TotalAmount', x = 'Quantity', data = online_retail_df_cleaned)
plt.show()

# %% [markdown]
# ->Giá trị Quantity âm -> khi nhân ra TotalAmount = Quantity * UnitPrice, dữ liệu sẽ có các giá trị âm cực lớn hoặc dương cực lớn → làm scatterplot bị méo.

# %%
online_retail_df_cleaned = online_retail_df_cleaned[online_retail_df_cleaned['Quantity'] > 0]
plt.figure(figsize = (12,6))
sns.scatterplot(y = 'TotalAmount', x = 'Quantity', data = online_retail_df_cleaned)
plt.xscale('log')
plt.yscale('log')
plt.show()

# %% [markdown]
# Khi dùng log scale, các giá trị lớn vẫn được giữ lại nhưng nhìn đồ thị cân bằng hơn, không bị “co cụm”.

# %% [markdown]
# #### Những tháng trong năm cùng tổng doanh thu thu được là gì ?

# %%
monthly_data = online_retail_df_cleaned.groupby('MonthYear')['TotalAmount'].sum().reset_index()
monthly_data['MonthYear'] = monthly_data['MonthYear'].astype(str)
fig, ax = plt.subplots(figsize=(6, 4)) 
fig.autofmt_xdate()  
plt.plot(monthly_data['MonthYear'], monthly_data['TotalAmount'], marker='o', linestyle='-', color='b')
plt.title('Total Purchase by Month')
plt.xlabel('MonthYear')
plt.ylabel('TotalAmount');

# %% [markdown]
# - `groupby('MonthYear')['TotalAmount'].sum()` → gom dữ liệu theo tháng và tính tổng doanh thu.
# - `astype(str)` → chuyển tháng thành chuỗi để vẽ trục x.
# - `plt.plot(..., marker='o')` → vẽ biểu đồ đường, đánh dấu từng điểm bằng chấm tròn.
# - `fig.autofmt_xdate()` → xoay nhãn trục x cho dễ đọc.
#
# **👉 Nhận xét:**
# - Doanh thu giảm đầu 2011, thấp nhất tháng **2011-04**.
# - Sau đó tăng mạnh, cao nhất tháng **2011-11 (~1.5 triệu)**.
# - Cuối năm (10–11) là **mùa cao điểm**, doanh thu bùng nổ.

# %% [markdown]
# #### Top 10 quốc gia với tổng doanh thu cao nhất

# %%
import seaborn as sns
import matplotlib.ticker as mtick
top_10_country = (online_retail_df_cleaned.groupby('Country')['TotalAmount'].sum().sort_values(ascending=False).head(10).reset_index())

plt.figure(figsize=(14,8))
sns.set(font_scale=1.5)

ax = sns.barplot(data=top_10_country, x='Country', y='TotalAmount', palette='Blues_r',hue='Country',legend=False);
ax.set_xlabel('Country')
plt.xticks(rotation=45); plt.ylabel('TotalAmount (Millions)'); plt.title('Top 10 Countries by TotalAmount')


ax.yaxis.set_major_formatter(mtick.FuncFormatter(lambda v, p: f'{v/1e6:.1f}M'))

# %% [markdown]
# - `groupby('Country')['TotalAmount'].sum()` → gom dữ liệu theo quốc gia và tính tổng doanh thu.
# - `sort_values(ascending=False).head(10)` → sắp xếp giảm dần, lấy **10 quốc gia cao nhất**.
# - `sns.barplot(..., palette='Blues_r')` → vẽ biểu đồ cột với màu xanh đảo ngược.
# - `mtick.FuncFormatter(lambda v, p: f'{v/1e6:.1f}M')` → định dạng trục y theo đơn vị triệu (M).
# - `plt.xticks(rotation=45)` → xoay nhãn quốc gia cho dễ đọc.
#
# **👉 Nhận xét:**
# - **United Kingdom** áp đảo tuyệt đối, doanh thu > **8 triệu**, cao gấp nhiều lần các nước khác.
# - Các quốc gia còn lại (Netherlands, EIRE, Germany, France, …) có doanh thu rất thấp, chỉ vài trăm nghìn.
# - Dataset tập trung chủ yếu ở **UK**, các nước khác đóng góp rất nhỏ.

# %%
online_retail_df_cleaned.groupby('Country')['TotalAmount'].sum()
#Nhóm tổng doanh thu các quốc gia và thống kê
# Out:
# Country
# Australia                138521.310
# Austria                   10198.680
# Bahrain                     754.140
# Belgium                   41196.340
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           20450.440
# Cyprus                    13590.380
# Czech Republic              826.740
# Denmark                   18955.340
# EIRE                     283453.960
# European Community         1300.250
# Finland                   22546.080
# France                   209715.110
# Germany                  228867.140
# Greece                     4760.520
# Hong Kong                 15691.800
# Iceland                    4310.000
# Israel                     8135.260
# Italy                     17483.240
# Japan                     37416.370
# Lebanon                    1693.880
# Lithuania                  1661.060
# Malta                      2725.590
# Netherlands              285446.340
# Norway                    36165.440
# Poland                     7334.650
# Portugal                  33747.100
# RSA                        1002.310
# Saudi Arabia                145.920
# Singapore                 21279.290
# Spain                     61577.110
# Sweden                    38378.330
# Switzerland               57089.900
# USA                        3580.390
# United Arab Emirates       1902.280
# United Kingdom          9003097.964
# Unspecified                4749.790
# Name: TotalAmount, dtype: float64

# %% [markdown]
# ### Ngày nào trong 1 tuần là bán chạy nhất ?

# %%
online_retail_df_cleaned.head()
online_retail_df_cleaned['Day_of_week'] = online_retail_df_cleaned['InvoiceDate'].dt.day_name()
daily_sales=online_retail_df_cleaned.groupby('Day_of_week')['TotalAmount'].sum()
order = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
daily_sales = daily_sales.reindex(order)
plt.figure(figsize=(9,7))
plt.bar(daily_sales.index, daily_sales.values);
ax=plt.gca()
ax.yaxis.set_major_formatter(mtick.FuncFormatter(lambda v, p: f'{v/1e6:.1f}M'))  
plt.tight_layout()
plt.xlabel('Day of week');
plt.ylabel('Total amount');

# %% [markdown]
# - `online_retail_df_cleaned['InvoiceDate'].dt.day_name()` → lấy tên ngày trong tuần từ cột `InvoiceDate`.
# - `groupby('Day_of_week')['TotalAmount'].sum()` → tính **tổng doanh thu** cho từng ngày trong tuần.
# - `order = [...]` + `reindex(order)` → sắp xếp thứ tự ngày từ Monday → Sunday.
# - `plt.bar(...)` → vẽ biểu đồ cột doanh thu theo ngày.
# - `mtick.FuncFormatter(lambda v, p: f'{v/1e6:.1f}M')` → hiển thị trục y theo đơn vị triệu (M).
#
# **👉 Nhận xét:**
# - Doanh thu cao nhất vào **Thursday** và **Tuesday**, khoảng trên 2 triệu.
# - **Sunday** là ngày doanh thu thấp nhất, chưa tới 1 triệu.
# - Nhìn chung, các ngày trong tuần (Mon–Fri) bán tốt hơn, còn cuối tuần (Sat–Sun) doanh thu giảm mạnh.

# %% [markdown]
# #### Top 10 mặt hàng bán chạy nhất all time

# %%
item_total_sell_most=online_retail_df_cleaned.groupby('Description')['TotalAmount'].sum()
most_value=item_total_sell_most.sort_values(ascending=False).head(10)
plt.figure(figsize=(10,7))
plt.bar(most_value.index, most_value.values,color='steelblue');
ax=plt.gca()
ax.yaxis.set_major_formatter(mtick.FuncFormatter(lambda v, p: f'{v/1e6:.1f}M'))  
plt.tight_layout()
plt.xticks(rotation=75,ha='right');
plt.xlabel('Product Description');
plt.ylabel('Total Sales (Millions)');

# %% [markdown]
# - `groupby('Description')['TotalAmount'].sum()` → tính **tổng doanh thu** cho từng sản phẩm.
# - `sort_values(ascending=False).head(10)` → lấy ra **10 sản phẩm có doanh thu cao nhất**.
# - `plt.bar(...)` → vẽ biểu đồ cột doanh thu theo sản phẩm.
# - `mtick.FuncFormatter(lambda v, p: f'{v/1e6:.1f}M')` → hiển thị trục y theo đơn vị **triệu (M)**.
# - `xticks(rotation=75)` → xoay nhãn tên sản phẩm để dễ đọc.
#
# **👉 Nhận xét:**
# - Sản phẩm **DOTCOM POSTAGE** có doanh thu cao nhất, vượt trội so với các mặt hàng khác.
# - Các sản phẩm thuộc nhóm **trang trí/đồ gia dụng** (ví dụ: `HANGING HEART T-LIGHT HOLDER`, `PARTY BUNTING`, `STORAGE JAR`...) chiếm nhiều trong top bán chạy.
# - Doanh thu của sản phẩm top 1 cao hơn hẳn so với nhóm còn lại, thể hiện sự mất cân đối trong cơ cấu bán hàng.

# %% [markdown]
# # **III. Phân tích dữ liệu đơn biến và hai biến**

# %% [markdown]
# #Bài tập: Thực hiện các yêu cầu sau:
# + Tìm hiểu các tính năng và cách sử dụng sản phẩm SweetViz (https://pypi.org/project/sweetviz)
# + Tìm hiểu các tính năng và cách sử dụng sản phẩm AutoViz (https://pypi.org/project/autoviz) <br>
# Note: Áp dụng trên tập dữ liệu Marketing Campaign: https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis

# %% [markdown]
# ### **1. TỔNG QUAN (Phần chung cho cả 3 phần bài tập)**

# %% [markdown]
# #### 1.1. Tóm tắt bài toán

# %% [markdown]
# <!-- Mô tả sơ vấn đề bài toán -->
# Mô tả bài toán:
# + Phân tích tính cách khách hàng là một phân tích chi tiết về những khách hàng lý tưởng của một công ty. Nó giúp doanh nghiệp hiểu rõ hơn về khách hàng của mình và giúp họ dễ dàng điều chỉnh sản phẩm theo nhu cầu, hành vi và mối quan tâm cụ thể của các loại khách hàng khác nhau.
#
# + Phân tích tính cách khách hàng giúp doanh nghiệp điều chỉnh sản phẩm của mình dựa trên các khách hàng mục tiêu từ các phân khúc khách hàng khác nhau. Ví dụ, thay vì chi tiền để tiếp thị một sản phẩm mới cho mọi khách hàng trong cơ sở dữ liệu của công ty, một công ty có thể phân tích phân khúc khách hàng nào có nhiều khả năng mua sản phẩm nhất và sau đó chỉ tiếp thị sản phẩm đó trên phân khúc cụ thể đó.

# %% [markdown]
# #### 1.2. Mô tả các biến

# %% [markdown]
# <!-- Giải thích sơ các biến -->

# %% [markdown]
# ### **2. THỰC HÀNH**

# %% [markdown]
# #### 2.1. Tìm hiểu các tính năng và cách sử dụng sản phẩm SweetViz (https://pypi.org/project/sweetviz)

# %% [markdown]
# <h3>Tải thư viện cần thiết: sweetviz</h3>

# %%
# !pip install sweetviz
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.3.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /usr/local/lib/python3.12/dist-packages (from sweetviz) (2.2.2)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from sweetviz) (2.0.2)
# Requirement already satisfied: matplotlib>=3.1.3 in /usr/local/lib/python3.12/dist-packages (from sweetviz) (3.10.0)
# Requirement already satisfied: tqdm>=4.43.0 in /usr/local/lib/python3.12/dist-packages (from sweetviz) (4.67.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from sweetviz) (1.16.2)
# Requirement already satisfied: jinja2>=2.11.1 in /usr/local/lib/python3.12/dist-packages (from sweetviz) (3.1.6)
# Requirement already satisfied: importlib-resources>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from sweetviz) (6.5.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.11.1->sweetviz) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.3->sweetviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.3->sweetviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.3->sweetviz) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.3->sweetviz) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.3->sweetviz) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.3->sweetviz) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.3->sweetviz) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.3->sweetviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.17.0)
# Downloading sweetviz-2.3.1-py3-none-any.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 27.6 MB/s eta 0:00:00
# Installing collected packages: sweetviz
# Successfully installed sweetviz-2.3.1

# %% [markdown]
# <h3>Import thư viện</h3>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sweetviz as sv

# %% [markdown]
# ##### 2.1.1. Phân tích dữ liệu đơn biến

# %%
# Thực hiện code ở đây (giống trong file pdf)

# %% [markdown]
# <!-- Giải thích code -->
# Giải thích code

# %% [markdown]
# ##### 2.1.2. Phân tích dữ liệu đa biến

# %%
# Thực hiện code ở đây (giống trong file pdf)

# %% [markdown]
# <!-- Giải thích code -->
# Giải thích code

# %% [markdown]
# #### 2.2. Tìm hiểu các tính năng và cách sử dụng sản phẩm AutoViz (https://pypi.org/project/autoviz)

# %% [markdown]
# ##### 2.2.1. Phân tích dữ liệu đơn biến

# %%
# !pip install autoviz
# Out:
# Collecting autoviz
#   Downloading autoviz-0.1.905-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.12/dist-packages (from autoviz) (2.0.2)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (from autoviz) (1.9.4)
# Collecting emoji (from autoviz)
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting pyamg (from autoviz)
#   Downloading pyamg-5.3.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from autoviz) (1.6.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (from autoviz) (0.14.5)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from autoviz) (3.9.1)
# Requirement already satisfied: textblob in /usr/local/lib/python3.12/dist-packages (from autoviz) (0.19.0)
# Collecting xgboost<1.7,>=0.82 (from autoviz)
#   Downloading xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: fsspec>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from autoviz) (2025.3.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from autoviz) (4.15.0)
# Collecting pandas-dq>=1.29 (from autoviz)
#   Downloading pandas_dq-1.29-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from autoviz) (2.0.2)
# Collecting hvplot>=0.9.2 (from autoviz)
#   Downloading hvplot-0.12.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: holoviews>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from autoviz) (1.21.0)
# Requirement already satisfied: panel>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from autoviz) (1.8.1)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.12/dist-packages (from autoviz) (2.2.2)
# Requirement already satisfied: matplotlib>3.7.4 in /usr/local/lib/python3.12/dist-packages (from autoviz) (3.10.0)
# Requirement already satisfied: seaborn>0.12.2 in /usr/local/lib/python3.12/dist-packages (from autoviz) (0.13.2)
# Requirement already satisfied: bokeh>=3.1 in /usr/local/lib/python3.12/dist-packages (from holoviews>=1.16.0->autoviz) (3.7.3)
# Requirement already satisfied: colorcet in /usr/local/lib/python3.12/dist-packages (from holoviews>=1.16.0->autoviz) (3.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from holoviews>=1.16.0->autoviz) (25.0)
# Requirement already satisfied: param<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from holoviews>=1.16.0->autoviz) (2.2.1)
# Requirement already satisfied: pyviz-comms>=2.1 in /usr/local/lib/python3.12/dist-packages (from holoviews>=1.16.0->autoviz) (3.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.7.4->autoviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.7.4->autoviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.7.4->autoviz) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.7.4->autoviz) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.7.4->autoviz) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.7.4->autoviz) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.7.4->autoviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->autoviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->autoviz) (2025.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from panel>=1.4.0->autoviz) (6.2.0)
# Requirement already satisfied: linkify-it-py in /usr/local/lib/python3.12/dist-packages (from panel>=1.4.0->autoviz) (2.0.3)
# Requirement already satisfied: markdown in /usr/local/lib/python3.12/dist-packages (from panel>=1.4.0->autoviz) (3.9)
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.12/dist-packages (from panel>=1.4.0->autoviz) (4.0.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.12/dist-packages (from panel>=1.4.0->autoviz) (0.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from panel>=1.4.0->autoviz) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from panel>=1.4.0->autoviz) (4.67.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->autoviz) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->autoviz) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->autoviz) (3.6.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->autoviz) (8.2.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk->autoviz) (2024.11.6)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels->autoviz) (1.0.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.1.6)
# Requirement already satisfied: narwhals>=1.13 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (2.5.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.4.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (2025.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>3.7.4->autoviz) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach->panel>=1.4.0->autoviz) (0.5.1)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.12/dist-packages (from linkify-it-py->panel>=1.4.0->autoviz) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py->panel>=1.4.0->autoviz) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->panel>=1.4.0->autoviz) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->panel>=1.4.0->autoviz) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->panel>=1.4.0->autoviz) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->panel>=1.4.0->autoviz) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.0.2)
# Downloading autoviz-0.1.905-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 2.3 MB/s eta 0:00:00
# Downloading hvplot-0.12.1-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 kB 6.4 MB/s eta 0:00:00
# Downloading pandas_dq-1.29-py3-none-any.whl (29 kB)
# Downloading xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl (255.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 3.8 MB/s eta 0:00:00
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 23.6 MB/s eta 0:00:00
# Downloading pyamg-5.3.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 40.5 MB/s eta 0:00:00
# Installing collected packages: emoji, xgboost, pyamg, pandas-dq, hvplot, autoviz
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 3.0.5
#     Uninstalling xgboost-3.0.5:
#       Successfully uninstalled xgboost-3.0.5
# Successfully installed autoviz-0.1.905 emoji-2.15.0 hvplot-0.12.1 pandas-dq-1.29 pyamg-5.3.0 xgboost-1.6.2

# %%
# Thực hiện code ở đây (giống trong file pdf)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from autoviz.AutoViz_Class import AutoViz_Class

# %%
df = pd.read_csv("marketing_campaign.csv", sep="\t")
AV = AutoViz_Class()

df_uni = AV.AutoViz(
    "",
    dfte=df,
    depVar="",   # để trống = univariate
)
# Out:
# Shape of your Data Set loaded: (2240, 29)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  1
#     Number of Integer-Categorical Columns =  15
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  7
#     Number of Discrete String Columns =  1
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  2
#     29 Predictors classified...
#         3 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['ID', 'Z_CostContact', 'Z_Revenue']
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_58453_row0_col0, #T_58453_row0_col2, #T_58453_row0_col3, #T_58453_row0_col4, #T_58453_row0_col5, #T_58453_row1_col0, #T_58453_row1_col2, #T_58453_row1_col3, #T_58453_row1_col4, #T_58453_row1_col5, #T_58453_row2_col0, #T_58453_row2_col2, #T_58453_row2_col3, #T_58453_row2_col4, #T_58453_row2_col5, #T_58453_row3_col0, #T_58453_row3_col2, #T_58453_row3_col3, #T_58453_row3_col4, #T_58453_row3_col5, #T_58453_row4_col0, #T_58453_row4_col2, #T_58453_row4_col3, #T_58453_row4_col4, #T_58453_row4_col5, #T_58453_row5_col0, #T_58453_row5_col2, #T_58453_row5_col3, #T_58453_row5_col4, #T_58453_row5_col5, #T_58453_row6_col0, #T_58453_row6_col2, #T_58453_row6_col3, #T_58453_row6_col4, #T_58453_row6_col5, #T_58453_row7_col0, #T_58453_row7_col2, #T_58453_row7_col3, #T_58453_row7_col4, #T_58453_row7_col5, #T_58453_row8_col0, #T_58453_row8_col2, #T_58453_row8_col3, #T_58453_row8_col4, #T_58453_row8_col5, #T_58453_row9_col0, #T_58453_row9_col2, #T_58453_row9_col3, #T_58453_row9_col4, #T_58453_row9_col5, #T_58453_row10_col0, #T_58453_row10_col2, #T_58453_row10_col3, #T_58453_row10_col4, #T_58453_row10_col5, #T_58453_row11_col0, #T_58453_row11_col2, #T_58453_row11_col3, #T_58453_row11_col4, #T_58453_row11_col5, #T_58453_row12_col0, #T_58453_row12_col2, #T_58453_row12_col3, #T_58453_row12_col4, #T_58453_row12_col5, #T_58453_row13_col0, #T_58453_row13_col2, #T_58453_row13_col3, #T_58453_row13_col4, #T_58453_row13_col5, #T_58453_row14_col0, #T_58453_row14_col2, #T_58453_row14_col3, #T_58453_row14_col4, #T_58453_row14_col5, #T_58453_row15_col0, #T_58453_row15_col2, #T_58453_row15_col3, #T_58453_row15_col4, #T_58453_row15_col5, #T_58453_row16_col0, #T_58453_row16_col2, #T_58453_row16_col3, #T_58453_row16_col4, #T_58453_row16_col5, #T_58453_row17_col0, #T_58453_row17_col2, #T_58453_row17_col3, #T_58453_row17_col4, #T_58453_row17_col5, #T_58453_row18_col0, #T_58453_row18_col2, #T_58453_row18_col3, #T_58453_row18_col4, #T_58453_row18_col5, #T_58453_row19_col0, #T_58453_row19_col2, #T_58453_row19_col3, #T_58453_row19_col4, #T_58453_row19_col5, #T_58453_row20_col0, #T_58453_row20_col2, #T_58453_row20_col3, #T_58453_row20_col4, #T_58453_row20_col5, #T_58453_row21_col0, #T_58453_row21_col2, #T_58453_row21_col3, #T_58453_row21_col4, #T_58453_row21_col5, #T_58453_row22_col0, #T_58453_row22_col2, #T_58453_row22_col3, #T_58453_row22_col4, #T_58453_row22_col5, #T_58453_row23_col0, #T_58453_row23_col2, #T_58453_row23_col3, #T_58453_row23_col4, #T_58453_row23_col5, #T_58453_row24_col0, #T_58453_row24_col2, #T_58453_row24_col3, #T_58453_row24_col4, #T_58453_row24_col5, #T_58453_row25_col0, #T_58453_row25_col2, #T_58453_row25_col3, #T_58453_row25_col4, #T_58453_row25_col5, #T_58453_row26_col0, #T_58453_row26_col2, #T_58453_row26_col3, #T_58453_row26_col4, #T_58453_row26_col5, #T_58453_row27_col0, #T_58453_row27_col2, #T_58453_row27_col3, #T_58453_row27_col4, #T_58453_row27_col5, #T_58453_row28_col0, #T_58453_row28_col2, #T_58453_row28_col3, #T_58453_row28_col4, #T_58453_row28_col5 {
#   font-family: Segoe UI;
# }
# #T_58453_row0_col1, #T_58453_row1_col1, #T_58453_row2_col1, #T_58453_row3_col1, #T_58453_row5_col1, #T_58453_row6_col1, #T_58453_row7_col1, #T_58453_row8_col1, #T_58453_row9_col1, #T_58453_row10_col1, #T_58453_row11_col1, #T_58453_row12_col1, #T_58453_row13_col1, #T_58453_row14_col1, #T_58453_row15_col1, #T_58453_row16_col1, #T_58453_row17_col1, #T_58453_row18_col1, #T_58453_row19_col1, #T_58453_row20_col1, #T_58453_row21_col1, #T_58453_row22_col1, #T_58453_row23_col1, #T_58453_row24_col1, #T_58453_row25_col1, #T_58453_row26_col1, #T_58453_row27_col1, #T_58453_row28_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_58453_row4_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_58453" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58453_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_58453_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_58453_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_58453_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_58453_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_58453_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58453_level0_row0" class="row_heading level0 row0" >ID</th>
#       <td id="T_58453_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_58453_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_58453_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_58453_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_58453_row0_col4" class="data row0 col4" >11191.000000</td>
#       <td id="T_58453_row0_col5" class="data row0 col5" >Possible ID column: drop before modeling step.</td>
#     </tr>
#     <tr>
#       <th id="T_58453_level0_row1" class="row_heading level0 row1" >Year_Birth</th>
#       <td id="T_58453_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_58453_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_58453_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_58453_row1_col3" class="data row1 col3" >1893.000000</td>
#       <td id="T_58453_row1_col4" class="data row1 col4" >1996.000000</td>
#       <td id="T_58453_row1_col5" class="data row1 col5" >Column has 3 outliers greater than upper bound (2004.00) or lower than lower bound(1932.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_58453_level0_row2" class="row_heading level0 row2" >Education</th>
#       <td id="T_58453_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_58453_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_58453_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_58453_row2_col3" class="data row2 col3" ></td>
#       <td id="T_58453_row2_col4" class="data row2 col4" ></td>
#       <td id="T_58453_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_58453_level0_row3" class="row_heading level0 row3" >Marital_Status</th>
#       <td id="T_58453_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_58453_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_58453_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_58453_row3_col3" class="data row3 col3" ></td>
#       <td id="T_58453_row3_col4" class="data row3 col4" ></td>
#       <td id="T_58453_row3_col5" class="data row3 col5" >3 rare categories: ['Alone', 'Absurd', 'YOLO']. Group them into a single category or drop the categories.</td>
#     </tr>
#     <tr>
#       <th id="T_58453_level0_row4" class="row_heading level0 row4" >Income</th>
#       <td id="T_58453_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_58453_row4_col1" class="data row4 col1" >1.071429</td>
#       <td id="T_58453_row4_col2" class="data row4 col2" >NA</td>
#       <td id="T_58453_row4_col3" class="data row4 col3" >1730.000000</td>
#       <td id="T_58453_row4_col4" class="data row4 col4" >666666.000000</td>
#       <td id="T_58453_row4_col5" class="data row4 col5" >24 missing values. Impute them with mean, median, mode, or a constant value such as 123., Column has 8 outliers greater than upper bound (118350.50) or lower than lower bound(-14525.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_58453_level0_row5" class="row_heading level0 row5" >Kidhome</th>
#       <td id="T_58453_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_58453_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_58453_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_58453_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_58453_row5_col4" class="data row5 col4" >2.000000</td>
#       <td id="T_58453_row5_col5" class="data row5 col5" >No issue</td>
#     </tr>
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# Could not draw wordcloud plot for Dt_Customer.
# Looks like you are missing some required data for this feature.
#
# To download the necessary data, simply run
#
#     python -m textblob.download_corpora
#
# or use the NLTK downloader to download the missing data: http://nltk.org/data.html
# If this doesn't fix the problem, file an issue at https://github.com/sloria/TextBlob/issues.
#
# All Plots done
# Time to run AutoViz = 6 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %% [markdown]
# # 📊 Giải thích kết quả AutoViz cho Marketing Campaign Dataset
#
# ### 1. Kích thước dữ liệu
# - Dataset có **2240 dòng** và **29 cột**.
#
# ### 2. Phân loại biến
# - Numeric Columns: 1
# - Integer-Categorical Columns: 15
# - String-Categorical Columns: 2
# - Numeric-Boolean Columns: 7
# - ID Columns: 1 → `ID` (nên loại bỏ)
# - Low information columns: `Z_CostContact`, `Z_Revenue` (có giá trị không thay đổi, nên loại bỏ)
#
# ### 3. Báo cáo chất lượng dữ liệu (DQ Report)
# - `Year_Birth`: Có outlier (giá trị ngoài khoảng hợp lý).
# - `Education`: Không vấn đề.
# - `Marital_Status`: Có các nhóm hiếm như `Alone`, `Absurd`, `YOLO` → nên gộp vào nhóm "Other".
# - `Income`: Có **24 giá trị thiếu** và nhiều outlier (ví dụ 666,666).
# - `Dt_Customer`: Có quá nhiều giá trị khác nhau (high cardinality) → nên mã hóa hoặc xử lý lại.
# - Các biến chi tiêu (`MntWines`, `MntFruits`, `MntMeatProducts`, …): Có nhiều outlier.
# - Các biến mua hàng (`NumDealsPurchases`, `NumWebPurchases`, …): Có outlier.
# - Các biến nhị phân (`AcceptedCmp1-5`, `Complain`, `Response`): Không vấn đề.
#
# ### 4. Lưu ý từ AutoViz
# - Đã tự động loại bỏ các cột: `['ID', 'Z_CostContact', 'Z_Revenue']`.
# - Gợi ý xử lý dữ liệu:
#   - Loại bỏ hoặc thay thế giá trị thiếu (`Income`).
#   - Gộp nhóm hiếm trong `Marital_Status`.
#   - Xử lý outlier (cắt giá trị hoặc dùng winsorization).
#   - Mã hóa `Dt_Customer` nếu muốn dùng trong mô hình.
#
# ### 5. Thông báo thêm
# - AutoViz cố vẽ **WordCloud** cho `Dt_Customer` nhưng thất bại (do là dữ liệu ngày tháng).
# - Đây không ảnh hưởng đến phân tích chính.
#
# ---
# ✅ **Kết luận**: AutoViz đã giúp ta nhanh chóng nhận diện **biến ID**, **cột ít thông tin**, **outlier**, và **missing values** trong dữ liệu Marketing Campaign.

# %% [markdown]
# <!-- Giải thích code -->
# Giải thích code

# %% [markdown]
# ##### 2.2.2. Phân tích dữ liệu đa biến

# %%
# Thực hiện code ở đây (giống trong file pdf)
df_multi = AV.AutoViz(
    "",
    dfte=df,
    depVar="Response"
)
# Out:
# Shape of your Data Set loaded: (2240, 29)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  1
#     Number of Integer-Categorical Columns =  15
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  6
#     Number of Discrete String Columns =  1
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  2
#     28 Predictors classified...
#         3 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['ID', 'Z_CostContact', 'Z_Revenue']
#
# ################ Binary_Classification problem #####################
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
# There are 182 duplicate rows in your dataset
#     Alert: Dropping duplicate rows can sometimes cause your column data types to change to object!
#     All variables classified into correct types.
# <style type="text/css">
# #T_26e6c_row0_col0, #T_26e6c_row0_col2, #T_26e6c_row0_col3, #T_26e6c_row0_col4, #T_26e6c_row0_col5, #T_26e6c_row1_col0, #T_26e6c_row1_col2, #T_26e6c_row1_col3, #T_26e6c_row1_col4, #T_26e6c_row1_col5, #T_26e6c_row2_col0, #T_26e6c_row2_col2, #T_26e6c_row2_col3, #T_26e6c_row2_col4, #T_26e6c_row2_col5, #T_26e6c_row3_col0, #T_26e6c_row3_col2, #T_26e6c_row3_col3, #T_26e6c_row3_col4, #T_26e6c_row3_col5, #T_26e6c_row4_col0, #T_26e6c_row4_col2, #T_26e6c_row4_col3, #T_26e6c_row4_col4, #T_26e6c_row4_col5, #T_26e6c_row5_col0, #T_26e6c_row5_col2, #T_26e6c_row5_col3, #T_26e6c_row5_col4, #T_26e6c_row5_col5, #T_26e6c_row6_col0, #T_26e6c_row6_col2, #T_26e6c_row6_col3, #T_26e6c_row6_col4, #T_26e6c_row6_col5, #T_26e6c_row7_col0, #T_26e6c_row7_col2, #T_26e6c_row7_col3, #T_26e6c_row7_col4, #T_26e6c_row7_col5, #T_26e6c_row8_col0, #T_26e6c_row8_col2, #T_26e6c_row8_col3, #T_26e6c_row8_col4, #T_26e6c_row8_col5, #T_26e6c_row9_col0, #T_26e6c_row9_col2, #T_26e6c_row9_col3, #T_26e6c_row9_col4, #T_26e6c_row9_col5, #T_26e6c_row10_col0, #T_26e6c_row10_col2, #T_26e6c_row10_col3, #T_26e6c_row10_col4, #T_26e6c_row10_col5, #T_26e6c_row11_col0, #T_26e6c_row11_col2, #T_26e6c_row11_col3, #T_26e6c_row11_col4, #T_26e6c_row11_col5, #T_26e6c_row12_col0, #T_26e6c_row12_col2, #T_26e6c_row12_col3, #T_26e6c_row12_col4, #T_26e6c_row12_col5, #T_26e6c_row13_col0, #T_26e6c_row13_col2, #T_26e6c_row13_col3, #T_26e6c_row13_col4, #T_26e6c_row13_col5, #T_26e6c_row14_col0, #T_26e6c_row14_col2, #T_26e6c_row14_col3, #T_26e6c_row14_col4, #T_26e6c_row14_col5, #T_26e6c_row15_col0, #T_26e6c_row15_col2, #T_26e6c_row15_col3, #T_26e6c_row15_col4, #T_26e6c_row15_col5, #T_26e6c_row16_col0, #T_26e6c_row16_col2, #T_26e6c_row16_col3, #T_26e6c_row16_col4, #T_26e6c_row16_col5, #T_26e6c_row17_col0, #T_26e6c_row17_col2, #T_26e6c_row17_col3, #T_26e6c_row17_col4, #T_26e6c_row17_col5, #T_26e6c_row18_col0, #T_26e6c_row18_col2, #T_26e6c_row18_col3, #T_26e6c_row18_col4, #T_26e6c_row18_col5, #T_26e6c_row19_col0, #T_26e6c_row19_col2, #T_26e6c_row19_col3, #T_26e6c_row19_col4, #T_26e6c_row19_col5, #T_26e6c_row20_col0, #T_26e6c_row20_col2, #T_26e6c_row20_col3, #T_26e6c_row20_col4, #T_26e6c_row20_col5, #T_26e6c_row21_col0, #T_26e6c_row21_col2, #T_26e6c_row21_col3, #T_26e6c_row21_col4, #T_26e6c_row21_col5, #T_26e6c_row22_col0, #T_26e6c_row22_col2, #T_26e6c_row22_col3, #T_26e6c_row22_col4, #T_26e6c_row22_col5, #T_26e6c_row23_col0, #T_26e6c_row23_col2, #T_26e6c_row23_col3, #T_26e6c_row23_col4, #T_26e6c_row23_col5, #T_26e6c_row24_col0, #T_26e6c_row24_col2, #T_26e6c_row24_col3, #T_26e6c_row24_col4, #T_26e6c_row24_col5, #T_26e6c_row25_col0, #T_26e6c_row25_col2, #T_26e6c_row25_col3, #T_26e6c_row25_col4, #T_26e6c_row25_col5 {
#   font-family: Segoe UI;
# }
# #T_26e6c_row0_col1, #T_26e6c_row1_col1, #T_26e6c_row2_col1, #T_26e6c_row4_col1, #T_26e6c_row5_col1, #T_26e6c_row6_col1, #T_26e6c_row7_col1, #T_26e6c_row8_col1, #T_26e6c_row9_col1, #T_26e6c_row10_col1, #T_26e6c_row11_col1, #T_26e6c_row12_col1, #T_26e6c_row13_col1, #T_26e6c_row14_col1, #T_26e6c_row15_col1, #T_26e6c_row16_col1, #T_26e6c_row17_col1, #T_26e6c_row18_col1, #T_26e6c_row19_col1, #T_26e6c_row20_col1, #T_26e6c_row21_col1, #T_26e6c_row22_col1, #T_26e6c_row23_col1, #T_26e6c_row24_col1, #T_26e6c_row25_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_26e6c_row3_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_26e6c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26e6c_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_26e6c_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_26e6c_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_26e6c_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_26e6c_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_26e6c_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26e6c_level0_row0" class="row_heading level0 row0" >Year_Birth</th>
#       <td id="T_26e6c_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_26e6c_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_26e6c_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_26e6c_row0_col3" class="data row0 col3" >1893.000000</td>
#       <td id="T_26e6c_row0_col4" class="data row0 col4" >1996.000000</td>
#       <td id="T_26e6c_row0_col5" class="data row0 col5" >Column has 3 outliers greater than upper bound (2004.00) or lower than lower bound(1932.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_26e6c_level0_row1" class="row_heading level0 row1" >Education</th>
#       <td id="T_26e6c_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_26e6c_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_26e6c_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_26e6c_row1_col3" class="data row1 col3" ></td>
#       <td id="T_26e6c_row1_col4" class="data row1 col4" ></td>
#       <td id="T_26e6c_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_26e6c_level0_row2" class="row_heading level0 row2" >Marital_Status</th>
#       <td id="T_26e6c_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_26e6c_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_26e6c_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_26e6c_row2_col3" class="data row2 col3" ></td>
#       <td id="T_26e6c_row2_col4" class="data row2 col4" ></td>
#       <td id="T_26e6c_row2_col5" class="data row2 col5" >3 rare categories: ['Alone', 'Absurd', 'YOLO']. Group them into a single category or drop the categories.</td>
#     </tr>
#     <tr>
#       <th id="T_26e6c_level0_row3" class="row_heading level0 row3" >Income</th>
#       <td id="T_26e6c_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_26e6c_row3_col1" class="data row3 col1" >1.166181</td>
#       <td id="T_26e6c_row3_col2" class="data row3 col2" >NA</td>
#       <td id="T_26e6c_row3_col3" class="data row3 col3" >1730.000000</td>
#       <td id="T_26e6c_row3_col4" class="data row3 col4" >666666.000000</td>
#       <td id="T_26e6c_row3_col5" class="data row3 col5" >24 missing values. Impute them with mean, median, mode, or a constant value such as 123., Column has 8 outliers greater than upper bound (117909.50) or lower than lower bound(-13900.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_26e6c_level0_row4" class="row_heading level0 row4" >Kidhome</th>
#       <td id="T_26e6c_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_26e6c_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_26e6c_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_26e6c_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_26e6c_row4_col4" class="data row4 col4" >2.000000</td>
#       <td id="T_26e6c_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_26e6c_level0_row5" class="row_heading level0 row5" >Teenhome</th>
#       <td id="T_26e6c_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_26e6c_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_26e6c_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_26e6c_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_26e6c_row5_col4" class="data row5 col4" >2.000000</td>
#       <td id="T_26e6c_row5_col5" class="data row5 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_26e6c_level0_row6" class="row_heading level0 row6" >Dt_Customer</th>
#       <td id="T_26e6c_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_26e6c_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_26e6c_row6_col2" class="data row6 col2" >32</td>
#       <td id="T_26e6c_row6_col3" class="data row6 col3" ></td>
#       <td id="T_26e6c_row6_col4" class="data row6 col4" ><
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# Could not draw wordcloud plot for Dt_Customer.
# Looks like you are missing some required data for this feature.
#
# To download the necessary data, simply run
#
#     python -m textblob.download_corpora
#
# or use the NLTK downloader to download the missing data: http://nltk.org/data.html
# If this doesn't fix the problem, file an issue at https://github.com/sloria/TextBlob/issues.
#
# All Plots done
# Time to run AutoViz = 7 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %% [markdown]
# # 📊 Giải thích kết quả AutoViz (Marketing Campaign)
#
# ### 1. Thông tin chung
# - Dataset sau khi load: **2240 dòng, 29 cột**
# - AutoViz tự động loại bỏ 3 cột ít thông tin: `['ID', 'Z_CostContact', 'Z_Revenue']`
# - Phát hiện: có **182 dòng trùng lặp** → nên cân nhắc loại bỏ
#
# ### 2. Loại biến
# - Numeric Columns: 1
# - Integer-Categorical: 15
# - String-Categorical: 2
# - Numeric-Boolean: 6
# - Discrete String: 1
# - ID Column: 1
# - DateTime Columns: 0
#
# ### 3. Báo cáo chất lượng dữ liệu (DQ Report)
# - **Year_Birth**: có 3 giá trị outlier (trước 1932 hoặc sau 2004).
# - **Marital_Status**: có 3 nhóm hiếm `['Alone', 'Absurd', 'YOLO']` → nên gộp thành “Other”.
# - **Income**: có 24 giá trị thiếu, và outlier (tối đa 666,666).
# - **Dt_Customer**: high cardinality (663 giá trị khác nhau) → mã hóa hoặc bỏ.
# - **Các cột chi tiêu** (`MntWines`, `MntFruits`, `MntMeatProducts`, `MntFishProducts`, `MntSweetProducts`, `MntGoldProds`): có rất nhiều outlier.
# - **Các cột mua hàng** (`NumDealsPurchases`, `NumWebPurchases`, `NumCatalogPurchases`, `NumWebVisitsMonth`): có outlier.
# - **Các biến nhị phân** (`AcceptedCmp1–5`, `Complain`, `Response`): ổn định, không vấn đề.
#
# ### 4. Lưu ý từ AutoViz
# - Đây là **Binary Classification problem** (biến mục tiêu: `Response`).
# - Có duplicate rows → cần xử lý trước khi train model.
# - AutoViz cố vẽ WordCloud cho `Dt_Customer` nhưng thất bại (do là ngày tháng, không phải text).
#
# ### 5. Kết luận
# - Dataset cần tiền xử lý:
#   - Loại bỏ/điều chỉnh outlier.
#   - Xử lý missing value (`Income`).
#   - Gộp nhóm hiếm (`Marital_Status`).
#   - Loại bỏ ID, low-information columns.
#   - Cân nhắc mã hóa `Dt_Customer`.
#   - Loại bỏ các dòng trùng lặp.
# - Sau bước cleaning, dữ liệu có thể dùng để xây dựng mô hình phân loại (`Response` = 0/1).

# %% [markdown]
# <!-- Giải thích code -->
# Giải thích code

# %% [markdown]
# ##### 2.2.3. Vẽ biểu đồ Phân tích dữ liệu đơn biến và đa biến

# %%
df_auto = AV.AutoViz(
    filename="",        # để trống nếu dùng dataframe
    sep=",",
    depVar="Response",  # biến mục tiêu (target)
    dfte=df,            # dataframe đã load sẵn
    header=0,
    verbose = 2
)
plt.show()
# Out:
# Shape of your Data Set loaded: (2240, 29)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#   Printing up to 30 columns (max) in each category:
#     Numeric Columns : ['Income']
#     Integer-Categorical Columns: ['Year_Birth', 'Kidhome', 'Teenhome', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth']
#     String-Categorical Columns: ['Education', 'Marital_Status']
#     Factor-Categorical Columns: []
#     String-Boolean Columns: []
#     Numeric-Boolean Columns: ['AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2', 'Complain']
#     Discrete String Columns: ['Dt_Customer']
#     NLP text Columns: []
#     Date Time Columns: []
#     ID Columns: ['ID']
#     Columns that will not be considered in modeling: ['Z_CostContact', 'Z_Revenue']
#     28 Predictors classified...
#         3 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['ID', 'Z_CostContact', 'Z_Revenue']
#
# ################ Binary_Classification problem #####################
#    Columns to delete:
# "   ['Z_CostContact', 'Z_Revenue']"
#    Boolean variables %s
# ("   ['AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', "
#  "'AcceptedCmp2', 'Complain']")
#    Categorical variables %s
# ("   ['Education', 'Marital_Status', 'Year_Birth', 'Kidhome', 'Teenhome', "
#  "'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', "
#  "'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases', "
#  "'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth', "
#  "'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', "
#  "'AcceptedCmp2', 'Complain']")
#    Continuous variables %s
# "   ['Income']"
#    Discrete string variables %s
# "   ['Dt_Customer']"
#    Date and time variables %s
# '   []'
#    ID variables %s
# "   ['ID']"
#    Target variable %s
# '   Response'
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
# There are 182 duplicate rows in your dataset
#     Alert: Dropping duplicate rows can sometimes cause your column data types to change to object!
#     All variables classified into correct types.
# <style type="text/css">
# #T_2363c_row0_col0, #T_2363c_row0_col2, #T_2363c_row0_col3, #T_2363c_row0_col4, #T_2363c_row0_col5, #T_2363c_row1_col0, #T_2363c_row1_col2, #T_2363c_row1_col3, #T_2363c_row1_col4, #T_2363c_row1_col5, #T_2363c_row2_col0, #T_2363c_row2_col2, #T_2363c_row2_col3, #T_2363c_row2_col4, #T_2363c_row2_col5, #T_2363c_row3_col0, #T_2363c_row3_col2, #T_2363c_row3_col3, #T_2363c_row3_col4, #T_2363c_row3_col5, #T_2363c_row4_col0, #T_2363c_row4_col2, #T_2363c_row4_col3, #T_2363c_row4_col4, #T_2363c_row4_col5, #T_2363c_row5_col0, #T_2363c_row5_col2, #T_2363c_row5_col3, #T_2363c_row5_col4, #T_2363c_row5_col5, #T_2363c_row6_col0, #T_2363c_row6_col2, #T_2363c_row6_col3, #T_2363c_row6_col4, #T_2363c_row6_col5, #T_2363c_row7_col0, #T_2363c_row7_col2, #T_2363c_row7_col3, #T_2363c_row7_col4, #T_2363c_row7_col5, #T_2363c_row8_col0, #T_2363c_row8_col2, #T_2363c_row8_col3, #T_2363c_row8_col4, #T_2363c_row8_col5, #T_2363c_row9_col0, #T_2363c_row9_col2, #T_2363c_row9_col3, #T_2363c_row9_col4, #T_2363c_row9_col5, #T_2363c_row10_col0, #T_2363c_row10_col2, #T_2363c_row10_col3, #T_2363c_row10_col4, #T_2363c_row10_col5, #T_2363c_row11_col0, #T_2363c_row11_col2, #T_2363c_row11_col3, #T_2363c_row11_col4, #T_2363c_row11_col5, #T_2363c_row12_col0, #T_2363c_row12_col2, #T_2363c_row12_col3, #T_2363c_row12_col4, #T_2363c_row12_col5, #T_2363c_row13_col0, #T_2363c_row13_col2, #T_2363c_row13_col3, #T_2363c_row13_col4, #T_2363c_row13_col5, #T_2363c_row14_col0, #T_2363c_row14_col2, #T_2363c_row14_col3, #T_2363c_row14_col4, #T_2363c_row14_col5, #T_2363c_row15_col0, #T_2363c_row15_col2, #T_2363c_row15_col3, #T_2363c_row15_col4, #T_2363c_row15_col5, #T_2363c_row16_col0, #T_2363c_row16_col2, #T_2363c_row16_col3, #T_2363c_row16_col4, #T_2363c_row16_col5, #T_2363c_row17_col0, #T_2363c_row17_col2, #T_2363c_row17_col3, #T_2363c_row17_col4, #T_2363c_row17_col5, #T_2363c_row18_col0, #T_2363c_row18_col2, #T_2363c_row18_col3, #T_2363c_row18_col4, #T_2363c_row18_col5, #T_2363c_row19_col0, #T_2363c_row19_col2, #T_2363c_row19_col3, #T_2363c_row19_col4, #T_2363c_row19_col5, #T_2363c_row20_col0, #T_2363c_row20_col2, #T_2363c_row20_col3, #T_2363c_row20_col4, #T_2363c_row20_col5, #T_2363c_row21_col0, #T_2363c_row21_col2, #T_2363c_row21_col3, #T_2363c_row21_col4, #T_2363c_row21_col5, #T_2363c_row22_col0, #T_2363c_row22_col2, #T_2363c_row22_col3, #T_2363c_row22_col4, #T_2363c_row22_col5, #T_2363c_row23_col0, #T_2363c_row23_col2, #T_2363c_row23_col3, #T_2363c_row23_col4, #T_2363c_row23_col5, #T_2363c_row24_col0, #T_2363c_row24_col2, #T_2363c_row24_col3, #T_2363c_row24_col4, #T_2363c_row24_col5, #T_2363c_row25_col0, #T_2363c_row25_col2, #T_2363c_row25_col3, #T_2363c_row25_col4, #T_2363c_row25_col5 {
#   font-family: Segoe UI;
# }
# #T_2363c_row0_col1, #T_2363c_row1_col1, #T_2363c_row2_col1, #T_2363c_row4_col1, #T_2363c_row5_col1, #T_2363c_row6_col1, #T_2363c_row7_col1, #T_2363c_row8_col1, #T_2363c_row9_col1, #T_2363c_row10_col1, #T_2363c_row11_col1, #T_2363c_row12_col1, #T_2363c_row13_col1, #T_2363c_row14_col1, #T_2363c_row15_col1, #T_2363c_row16_col1, #T_2363c_row17_col1, #T_2363c_row18_col1, #T_2363c_row19_col1, #T_2363c_row20_col1, #T_2363c_row21_col1, #T_2363c_row22_col1, #T_2363c_row23_col1, #T_2363c_row24_col1, #T_2363c_row25_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_2363c_row3_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_2363c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2363c_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_2363c_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_2363c_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_2363c_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_2363c_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_2363c_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2363c_level0_row0" class="row_heading level0 row0" >Year_Birth</th>
#       <td id="T_2363c_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_2363c_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_2363c_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_2363c_row0_col3" class="data row0 col3" >1893.000000</td>
#       <td id="T_2363c_row0_col4" class="data row0 col4" >1996.000000</td>
#       <td id="T_2363c_row0_col5" class="data row0 col5" >Column has 3 outliers greater than upper bound (2004.00) or lower than lower bound(1932.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_2363c_level0_row1" class="row_heading level0 row1" >Education</th>
#       <td id="T_2363c_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_2363c_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_2363c_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_2363c_row1_col3" class="data row1 col3" ></td>
#       <td id="T_2363c_row1_col4" class="data row1 col4" ></td>
#       <td id="T_2363c_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_2363c_level0_row2" class="row_heading level0 row2" >Marital_Status</th>
#       <td id="T_2363c_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_2363c_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_2363c_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_2363c_row2_col3" class="data row2 col3" ></td>
#       <td id="T_2363c_row2_col4" class="data row2 col4" ></td>
#       <td id="T_2363c_row2_col5" class="data row2 col5" >3 rare categories: ['Alone', 'Absurd', 'YOLO']. Group them into a single category or drop the categories.</td>
#     </tr>
#     <tr>
#       <th id="T_2363c_level0_row3" class="row_heading level0 row3" >Income</th>
#       <td id="T_2363c_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_2363c_row3_col1" class="data row3 col1" >1.166181</td>
#       <td id="T_2363c_row3_col2" class="data row3 col2" >NA</td>
#       <td id="T_2363c_row3_col3" class="data row3 col3" >1730.000000</td>
#       <td id="T_2363c_row3_col4" class="data row3 col4" >666666.000000</td>
#       <td id="T_2363c_row3_col5" class="data row3 col5" >24 missing values. Impute them with mean, median, mode, or a constant value such as 123., Column has 8 outliers greater than upper bound (117909.50) or lower than lower bound(-13900.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_2363c_level0_row4" class="row_heading level0 row4" >Kidhome</th>
#       <td id="T_2363c_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_2363c_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_2363c_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_2363c_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_2363c_row4_col4" class="data row4 col4" >2.000000</td>
#       <td id="T_2363c_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_2363c_level0_row5" class="row_heading level0 row5" >Teenhome</th>
#       <td id="T_2363c_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_2363c_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_2363c_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_2363c_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_2363c_row5_col4" class="data row5 col4" >2.000000</td>
#       <td id="T_2363c_row5_col5" class="data row5 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_2363c_level0_row6" class="row_heading level0 row6" >Dt_Customer</th>
#       <td id="T_2363c_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_2363c_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_2363c_row6_col2" class="data row6 col2" >32</td>
#       <td id="T_2363c_row6_col3" class="data row6 col3" ></td>
#       <td id="T_2363c_row6_col4" class="data row6 col4" ><
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# Could not draw wordcloud plot for Dt_Customer.
# Looks like you are missing some required data for this feature.
#
# To download the necessary data, simply run
#
#     python -m textblob.download_corpora
#
# or use the NLTK downloader to download the missing data: http://nltk.org/data.html
# If this doesn't fix the problem, file an issue at https://github.com/sloria/TextBlob/issues.
#
# All Plots are saved in ./AutoViz_Plots/Response
# Time to run AutoViz = 10 seconds

# %% [markdown]
# ### load ảnh các biểu đồ

# %%
import os
from IPython.display import SVG, display

plot_folder = "AutoViz_Plots/Response"

# Gom nhóm tên file theo loại biểu đồ
univariate_keywords = ["hist", "box", "bar"]   # đơn biến
multivariate_keywords = ["scatter", "corr", "pair"]  # đa biến

# %% [markdown]
# ## Biểu đồ đơn biến

# %%
print("📊 Biểu đồ đơn biến (Univariate Analysis):")
for file in sorted(os.listdir(plot_folder)):
    if file.endswith(".svg") and any(key in file.lower() for key in univariate_keywords):
        display(SVG(filename=os.path.join(plot_folder, file)))
# Out:
# 📊 Biểu đồ đơn biến (Univariate Analysis):

# %% [markdown]
# 📊 Giải thích các biểu đồ đơn biến (Univariate Analysis)
# 1. Histogram (Biểu đồ tần suất)
#
# Mục đích: mô tả phân bố của một biến liên tục hoặc rời rạc.
#
# Cách đọc:
#
# Trục X: giá trị của biến.
#
# Trục Y: số lần xuất hiện (tần suất).
#
# Ý nghĩa:
#
# Cho biết biến có phân phối chuẩn hay lệch trái/phải.
#
# Phát hiện giá trị bất thường (outlier).
#
# Ví dụ: thu nhập khách hàng tập trung nhiều ở mức trung bình, ít ở mức rất cao.
#
# 2. Boxplot (Biểu đồ hộp)
#
# Mục đích: mô tả độ phân tán và phát hiện ngoại lệ.
#
# Cách đọc:
#
# Hộp: chứa 50% dữ liệu (từ Q1 đến Q3).
#
# Đường giữa hộp: median (trung vị).
#
# Râu (whisker): khoảng dữ liệu trong giới hạn 1.5 * IQR.
#
# Điểm ngoài râu: ngoại lệ (outliers).
#
# Ý nghĩa:
#
# Giúp so sánh mức độ phân tán giữa các biến.
#
# Xác định biến có nhiều ngoại lệ hay không.
#
# 3. Bar chart (Biểu đồ cột)
#
# Mục đích: mô tả tần suất xuất hiện của các giá trị trong biến phân loại (categorical).
#
# Cách đọc:
#
# Trục X: các hạng mục (ví dụ: nghề nghiệp, tình trạng hôn nhân).
#
# Trục Y: số lượng hoặc tỷ lệ.
#
# Ý nghĩa:
#
# Cho biết hạng mục nào phổ biến nhất.
#
# So sánh trực quan tỷ lệ giữa các nhóm.
#
# Ví dụ: khách hàng kết hôn chiếm nhiều hơn so với khách hàng độc thân.
#
# 📌 Tóm tắt
#
# Histogram → Phân phối dữ liệu (chuẩn hay lệch).
#
# Boxplot → Độ phân tán + ngoại lệ.
#
# Bar chart → Tần suất của biến phân loại.

# %% [markdown]
# ## Biểu đồ đa biến

# %%
print("🔗 Biểu đồ đa biến (Multivariate Analysis):")
for file in sorted(os.listdir(plot_folder)):
    if file.endswith(".svg") and any(key in file.lower() for key in multivariate_keywords):
        display(SVG(filename=os.path.join(plot_folder, file)))
# Out:
# 🔗 Biểu đồ đa biến (Multivariate Analysis):
